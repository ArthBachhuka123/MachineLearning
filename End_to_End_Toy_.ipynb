# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthBachhuka123/MachineLearning/blob/main/End_to_End_Toy_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("placement (1).csv")

# %%
data.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
data = data.iloc[:,1:5]

# %%
import matplotlib.pyplot as plt

# %%
data
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
plt.bar(data["placement"],data["cgpa"])
# Out:
# <BarContainer object of 100 artists>

# %%
plt.plot(data["cgpa"])

# %%
plt.plot(data["iq"])

# %%
plt.scatter(data["iq"],data["cgpa"],c=data["placement"].map({1:"red",0:"black"}))

# %%
data[data["cgpa"]>=6]["placement"].value_counts()
# Out:
# placement
# 1    48
# 0     6
# Name: count, dtype: int64

# %%
X = data.iloc[:,0:2]
y = data["placement"]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 2.26836998e-01, -2.70512927e-01],
#        [ 4.89256271e-02, -1.41851361e+00],
#        [ 4.93704055e-01, -8.32300494e-01],
#        [-8.40631229e-01, -1.48385195e-01],
#        [ 1.37881313e-01,  1.93572455e-01],
#        [ 1.38326091e+00, -1.54064134e+00],
#        [-1.10749829e+00, -7.51085552e-02],
#        [-1.46332103e+00,  1.85450961e+00],
#        [-7.51675544e-01, -1.41851361e+00],
#        [-2.35287789e+00,  1.43927532e+00],
#        [-7.51675544e-01,  1.26829650e+00],
#        [-7.51675544e-01,  9.58702697e-02],
#        [-9.29586915e-01,  7.55360023e-01],
#        [-1.28985744e-01,  1.02404103e+00],
#        [-1.73018809e+00, -1.19868369e+00],
#        [ 9.38482484e-01,  1.83008407e+00],
#        [ 1.65012797e+00, -2.46087380e-01],
#        [ 5.82659741e-01, -9.95341017e-02],
#        [-6.62719858e-01,  1.93572455e-01],
#        [-1.01854260e+00,  4.13402373e-01],
#        [-1.01854260e+00,  1.09731767e+00],
#        [ 1.38326091e+00,  8.28636662e-01],
# ...

# %%
X_test
# Out:
# array([[ 0.67161543,  1.41484978],
#        [-0.48480849, -0.41706621],
#        [-0.12898574,  0.43782792],
#        [ 1.82803934, -1.1009815 ],
#        [-0.92958691, -1.54064134],
#        [ 0.58265974,  0.34012573],
#        [ 0.49370406,  0.87748776],
#        [-0.66271986, -0.83230049],
#        [ 1.4722166 , -0.85672604],
#        [ 0.93848248, -0.29493847],
#        [-1.73018809, -0.58804503],
#        [ 0.8495268 , -0.68574722],
#        [ 0.76057111, -0.83230049],
#        [-0.92958691,  0.65765784],
#        [ 2.0949064 ,  1.07289213],
#        [-0.84063123, -0.80787495],
#        [ 0.76057111, -0.29493847],
#        [-1.37436534,  0.60880674],
#        [-0.21794143,  0.38897683],
#        [ 0.93848248,  1.24387095]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_test
# Out:
# 97    1
# 81    0
# 4     0
# 58    1
# 73    0
# 48    1
# 38    1
# 28    0
# 42    1
# 29    1
# 18    0
# 66    1
# 35    1
# 89    0
# 53    1
# 25    0
# 93    1
# 88    0
# 36    0
# 52    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train,y_train.values,clf=model,legend=2)
# Out:
# <Axes: >
