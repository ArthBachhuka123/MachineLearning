# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthBachhuka123/MachineLearning/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Age
# **Conclusions**
# - skewness id good
# - there are some outliers
# - almost 20% of data is missing

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["Age"].plot(kind = "kde",figsize=(4,3))
# Out:
# <Axes: ylabel='Density'>

# %%
df["Age"].skew() #0 ke paas is good
# Out:
# np.float64(0.38910778230082704)

# %%
df["Age"].plot(kind = "box",figsize=(4,3))
# Out:
# <Axes: >

# %%
df[df["Age"]>60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
df["Age"].isnull().sum()/df["Age"].shape[0] #There is almost 20% missing values
# Out:
# np.float64(0.19865319865319866)

# %% [markdown]
# # Fare
# conclusions
# - data is highly positively skewed
# - Fare column contains the group fare and not individual fare of passengers , This might be a serious issue , we might have to feature engineer and add a new column

# %%
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df["Fare"].plot(kind = "kde",figsize=(4,3))
# Out:
# <Axes: ylabel='Density'>

# %%
df["Fare"].skew() # highly positively skewed
# Out:
# np.float64(4.787316519674893)

# %%
df["Fare"].plot(kind = "box",figsize=(4,4))
# Out:
# <Axes: >

# %%
df[df["Fare"]>250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df["Fare"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #Survived
# conclusion
# - it was a deadly accident as more than 60% of the people died
# - there are no missing values

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Survived"].value_counts().plot(kind="bar",figsize=(4,3))
# Out:
# <Axes: xlabel='Survived'>

# %%
df["Survived"].value_counts().plot(kind="pie",autopct="%0.1f%%",figsize=(4,3))
# Out:
# <Axes: ylabel='count'>

# %%
df["Survived"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #Pclass
# conclusions
# - there were mostly class 3 passengers
# - surprisingly 2nd class has least passengers
# - there are no missing values

# %%
df["Pclass"].head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Pclass, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts().plot(kind = "bar" , figsize = (4,3))
# Out:
# <Axes: xlabel='Pclass'>

# %%
df["Pclass"].value_counts().plot(kind = "pie", autopct="%0.1f%%" , figsize = (4,3))
# Out:
# <Axes: ylabel='count'>

# %%
df["Pclass"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Sex
# conclusions
# - the distribution looks normal
# - no such points to highlight

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Sex"].value_counts().plot(kind="bar",figsize=(4,3))
# Out:
# <Axes: xlabel='Sex'>

# %%
df["Sex"].value_counts().plot(kind="pie",autopct="%0.1f%%",figsize=(4,3))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # SibSp (siblings and family)
# conclusions
# - most passengers were travelling alone
# - there are no missing values

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df["SibSp"].value_counts().plot(kind="bar", figsize=(4,3))
# Out:
# <Axes: xlabel='SibSp'>

# %%
df["SibSp"].value_counts().plot(kind="pie",autopct="%0.1f%%", figsize=(12,6))
# Out:
# <Axes: ylabel='count'>

# %%
df["SibSp"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #Parch
# conclusions
# - Most passengers were travelling without children
# - There are no missing values
# - Parch and SibSp can be merged to Family count
# - We can also make a new column named IsAlone

# %%
df["Parch"].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df["Parch"].value_counts().plot(kind="bar", figsize=(4,3))
# Out:
# <Axes: xlabel='Parch'>

# %%
df["Parch"].value_counts().plot(kind="pie",autopct="%0.1f%%", figsize=(12,6))
# Out:
# <Axes: ylabel='count'>

# %%
df["Parch"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #BIVARIATE ANALYSIS
#
# 1. survived and others
#  # conclusions
#  a) Pclass
#  - Pclass 3 was the most dangerous class. → Passengers in Pclass 3 had the lowest survival rate.
#  - pclass 1 was the safest.
#
#   b) Sex
#  - females survived more than males
#
#  c) Embarked
#  - passengers from C were majorly in pclass 1 hence thay have a best survival rate
#
#  - passengers from S were majorly males and also from pclass 3 because of which the have a highest death rate
#
#  - passengers from Q were majorly(more than 93%) from pclass 3 , although the male female distribution was not significant still they have the 2nd highest death rate

# %%
import seaborn as sns
sns.heatmap(pd.crosstab(df["Survived"],df["Pclass"]))
plt.rcParams["figure.figsize"] = (4, 3)

# %%
pd.crosstab(df["Survived"],df["Pclass"],normalize="columns")*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
pd.crosstab(df["Survived"],df["Sex"])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(df["Survived"],df["Sex"],normalize="columns")*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
pd.crosstab(df["Survived"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df["Sex"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
pd.crosstab(df["Pclass"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
df[df["Survived"]==1]["Age"].plot(kind = "kde",figsize=(5,6))
df[df["Survived"]==0]["Age"].plot(kind = "kde",figsize=(5,6))
plt.legend()
plt.show()

# %% [markdown]
# # Feature Engineering
# **Making new columns , Individual_Fare , Family_count , Family_type , Deck , title , Surname**
#
# Conclusions
#
# - Small family has the highest survival rate
# - Big family have the highest death rate
# - B deck has the highest survival count in know sets
# - We can group deck A,B .. C,D,E .. F,G together as they provide similar informations

# %%
df1 = pd.read_csv("test (1).csv")

# %%
df = pd.concat([df,df1])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual_Fare  \
# 0      0         A/5 21171   7.2500     M        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250     M        S          7.92500
# ...

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    1457
# 1     539
# 2      70
# 4      30
# 3      28
# 8      13
# 5       8
# Name: count, dtype: int64

# %%
df[df["SibSp"]==8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 360         1252       NaN       3        Sage, Master. William Henry    male
# ...

# %%
df["Individual_Fare"] = df["Fare"]/(df["SibSp"]+df["Parch"]+1)

# %%
df[df["SibSp"]==8]["Individual_Fare"]
# Out:
# 159    6.322727
# 180    6.322727
# 201    6.322727
# 324    6.322727
# 792    6.322727
# 846    6.322727
# 863    6.322727
# 188    6.322727
# 360    6.322727
# 188    6.322727
# 360    6.322727
# 188    6.322727
# 360    6.322727
# Name: Individual_Fare, dtype: float64

# %%
df["Individual_Fare"].plot(kind = "box")
# Out:
# <Axes: >

# %%
df["Individual_Fare"].describe()
# Out:
# count    2142.000000
# mean       21.018906
# std        35.710873
# min         0.000000
# 25%         7.550000
# 50%         8.662500
# 75%        25.741700
# max       512.329200
# Name: Individual_Fare, dtype: float64

# %%
df[df["Fare"]==512.329200]
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259       1.0       1
# 679          680       1.0       1
# 737          738       1.0       1
# 343         1235       NaN       1
# 343         1235       NaN       1
# 343         1235       NaN       1
#
#                                                   Name     Sex   Age  SibSp  \
# 258                                   Ward, Miss. Anna  female  35.0      0
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 737                             Lesurer, Mr. Gustave J    male  35.0      0
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked  Individual_Fare  \
# 258      0  PC 17755  512.3292            M        C         512.3292
# ...

# %%
df["Family_count"] = df["SibSp"] + df["Parch"] + 1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def type(size):
  if(size == 1):
    return "Alone"
  elif(size>1 and size<=4):
    return "Small"
  else:
    return "Big"

# %%
df["Family_type"] = df["Family_count"].apply(type)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df["Survived"],df["Family_type"],normalize="columns")*100
# Out:
# Family_type      Alone        Big      Small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %%
pd.crosstab(df["Survived"],df["Family_type"]).plot(kind="bar",figsize=(4,3))
# Out:
# <Axes: xlabel='Survived'>

# %%
def surname(name):
  return name.split(",")[0]

# %%
df["Surname"] = df["Name"].apply(surname)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Surname"]=="Braund"]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 0              1       0.0       3    Braund, Mr. Owen Harris  male  22.0
# 477          478       0.0       3  Braund, Mr. Lewis Richard  male  29.0
#
#      SibSp  Parch     Ticket    Fare Cabin Embarked  Individual_Fare  \
# 0        1      0  A/5 21171  7.2500     M        S           3.6250
# 477      1      0       3460  7.0458     M        S           3.5229
#
#      Family_count Family_type Surname title Deck
# 0               2       Small  Braund   Mr.    M
# 477             2       Small  Braund   Mr.    M

# %%
df["Surname"].value_counts()
# Out:
# Surname
# Sage            19
# Asplund         16
# Davies          15
# Andersson       15
# Thomas          13
#                 ..
# Edvardsson       1
# Sawyer           1
# Turja            1
# Peters           1
# Silverthorne     1
# Name: count, Length: 875, dtype: int64

# %%
def title(name):
  return name.split(",")[1].strip().split(" ")[0]

# %%
df["title"] = df["Name"].apply(title)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["title"]=df["title"].str.replace("Rev.","other")
df["title"]=df["title"].str.replace("Col.","other")
df["title"]=df["title"].str.replace("Major.","other")
df["title"]=df["title"].str.replace("Don.","other")
df["title"]=df["title"].str.replace("Capt.","other")
df["title"]=df["title"].str.replace("Jonkheer.","other")
df["title"]=df["title"].str.replace("the","other")
df["title"]=df["title"].str.replace("Mme.","other")

# %%
df["title"].value_counts()
# Out:
# title
# Mr.        1237
# Miss.       416
# Mrs.        341
# Master.     103
# ootherr      25
# Dr.          10
# Ms.           4
# Dona.         3
# other         2
# Mlle.         2
# Sir.          1
# Lady.         1
# Name: count, dtype: int64

# %%
df["title"] = df["title"].str.replace("ootherr.","other")
df["title"] = df["title"].str.replace("ootherra.","other")

# %%
df["title"].value_counts()
# Out:
# title
# Mr.        1237
# Miss.       416
# Mrs.        341
# Master.     103
# ootherr      25
# Dr.          10
# Ms.           4
# Dona.         3
# other         2
# Mlle.         2
# Sir.          1
# Lady.         1
# Name: count, dtype: int64

# %%
df["Cabin"].value_counts()
# Out:
# Cabin
# M                  1341
# B57 B59 B63 B66      11
# C23 C25 C27          10
# C78                   8
# F4                    8
#                    ...
# F38                   1
# D6                    1
# B82 B84               1
# A36                   1
# B102                  1
# Name: count, Length: 187, dtype: int64

# %%
df["Deck"]=df["Cabin"].str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Cabin"].fillna("M",inplace=True)
# Out:
# /tmp/ipython-input-3691106463.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Cabin"].fillna("M",inplace=True)

# %%
df["Deck"].fillna("M",inplace=True)
# Out:
# /tmp/ipython-input-2807538620.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Deck"].fillna("M",inplace=True)

# %%
pd.crosstab(df["Deck"],df["Survived"],normalize="columns")*100
# Out:
# Survived        0.0        1.0
# Deck
# A          1.457195   2.046784
# B          2.185792  10.233918
# C          4.371585  10.233918
# D          1.457195   7.309942
# E          1.457195   7.017544
# F          0.910747   2.339181
# G          0.364299   0.584795
# M         87.613843  60.233918
# T          0.182149   0.000000

# %%
pd.crosstab(df["Deck"],df["Pclass"])
# Out:
# Pclass    1    2     3
# Deck
# A        36    0     0
# B       101    0     0
# C       164    0     0
# D        62   10     0
# E        52    4     3
# F         0   23    14
# G         0    0     7
# M       121  426  1121
# T         1    0     0

# %%
pd.crosstab(df["Deck"],df["Pclass"]).plot(kind="bar",figsize=(12,8))
# Out:
# <Axes: xlabel='Deck'>

# %%
pd.crosstab(df["Survived"],df["Deck"])
# Out:
# Deck      A   B   C   D   E  F  G    M  T
# Survived
# 0.0       8  12  24   8   8  5  2  481  1
# 1.0       7  35  35  25  24  8  2  206  0

# %%
pd.crosstab(df["Survived"],df["Deck"]).plot(kind="bar",figsize=(12,8))
# Out:
# <Axes: xlabel='Survived'>
